# %%
# 16. Accept any three string from one input() cal
n=input("enter three name:")
s=n.split()
t1=s[0]
t2=s[1]
t3=s[2]
print(t1)
print(t2)
print(t3)
# Out:
# enter three name: sumant anant gouda
# sumant
# anant
# gouda
