# %%
# 23. Write a python program to search a given number from a list
l1=[2,4,5,7,8,4,11,22,33,44,55,667,77,88,99]
n=int(input("Enter number:"))
if n in l1:
    print(f"{n} is exist in list")
else:
    print(f"{n} is not exist in list")
# Out:
# Enter number: 88
# 88 is exist in list
