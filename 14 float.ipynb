# %%
# 14.  Accept a list of 5 float numbers as an input from the user
l=[]
while len(l)<5:
    n=float(input("enter float number:"))
    l.append(n)
print(l)
# Out:
# enter float number: 34.5
# enter float number: 43.5
# enter float number: 88.7
# enter float number: 64.
# enter float number: 54.5
# [34.5, 43.5, 88.7, 64.0, 54.5]
