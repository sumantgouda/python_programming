# %%
# 26. Calculate income tax for the given income by adhering to the below rules first 10k--> 0% second 10 --> 10% remaining-->20%
n=float(input("Enter number:"))
if n<10000:
    tax=0
elif n>10000:
    tax=(n-10000)*0.1
else:
    tax=(10000*0.1)+(n-20000)*0.2
print(f"Total Tax to be paid:{tax}")
# Out:
# Enter number: 45000
# Total Tax to be paid:3500.0
