# %%
''' Format variables using a string.format() method. Write a program to use string.format() method
to format the following three variables as per the expected output
total money=1000
quantity=3
price=450

excepted output:
I have 1000 dolors so i can buy 3 football for 450.00 dolors'''

totalmoney=1000
quantity=3
price=450
print("I have {} dolors so i can buy {} football for {} dolors".format(totalmoney,quantity,price))
# Out:
# I have 1000 dolors so i can buy 3 football for 450 dolors
