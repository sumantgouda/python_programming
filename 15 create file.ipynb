# %%
# create a file and write and display the content of file 
f1=open(r"C:\Users\DELL\Desktop\test.txt","w")
f1.write("Hello!, Good Morning")
f1.close()

# %%
f1=open(r"C:\Users\DELL\Desktop\test.txt","r")
f1.read()
# Out:
# 'Hello!, Good Morning'
